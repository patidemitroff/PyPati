# %% [markdown]
# <a href="https://colab.research.google.com/github/patidemitroff/PyPati/blob/main/teste_filmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv("ratings.csv")
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
notas = pd.read_csv("ratings.csv")

# %%
notas.groupby("userId").mean()
# Out:
#              movieId    rating     timestamp
# userId
# 1        1854.603448  4.366379  9.649856e+08
# 2       70350.275862  3.948276  1.445715e+09
# 3        7058.384615  2.435897  1.306464e+09
# 4        1982.129630  3.555556  9.658643e+08
# 5         343.840909  3.636364  8.474351e+08
# ...              ...       ...           ...
# 606      9692.197309  3.657399  1.179512e+09
# 607      1860.636364  3.786096  9.647841e+08
# 608      4502.605295  3.134176  1.122668e+09
# 609       483.162162  3.270270  8.472210e+08
# 610     49590.231183  3.688556  1.489454e+09
#
# [610 rows x 3 columns]

# %%
notas.groupby("movieId").mean()
# Out:
#              userId    rating     timestamp
# movieId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
notas.groupby("movieId").mean()
# Out:
#              userId    rating     timestamp
# movieId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
notas.rating.plot(kind='hist')
#plot traz o grafico e kind argument traz a biblioteca de tipos de
#graficos disponiveis no panda
# Out:
# <Axes: ylabel='Frequency'>

# %%
notas.rating.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(notas.rating)
# Out:
# <Axes: ylabel='rating'>

# %%
notas.query("movieId==1").rating.mean()
# Out:
# 3.9209302325581397

# %%
notas.query("movieId==2").rating.mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby("movieId").mean().rating
medias_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64
